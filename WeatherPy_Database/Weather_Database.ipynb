# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e67bae4b8f4d959828f048359f17a790

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_description= city_weather["weather"][0]["description"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Description": city_description,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | manzanillo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | ahipara
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | lompoc
# Processing Record 8 of Set 1 | dangriga
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | leningradskiy
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | mawlaik
# Processing Record 13 of Set 1 | faya
# Processing Record 14 of Set 1 | la ronge
# Processing Record 15 of Set 1 | sentyabrskiy
# 'coord'
# Processing Record 16 of Set 1 | samusu
# 'coord'
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | saldanha
# Processing Record 19 of Set 1 | thompson
# Processing Record 20 of Set 1 | olga
# Processing Record 21 of Set 1 | kapoeta
# Processing Record 22 of Set 1 | dryden
# Processing Record 23 of Set 1 | siteki
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | santa maria
# Processing Record 29 of Set 1 | ibra
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | beatrice
# Processing Record 32 of Set 1 | beringovskiy
# Processing Record 33 of Set 1 | seoul
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | kupang
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | vaitupu
# 'coord'
# Processing Record 39 of Set 1 | narsaq
# Processing Record 40 of Set 1 | salym
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | methoni
# Processing Record 43 of Set 1 | maridi
# Processing Record 44 of Set 1 | la libertad
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | ouesso
# Processing Record 47 of Set 1 | plettenberg bay
# Processing Record 48 of Set 1 | vargashi
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | barentsburg
# 'coord'
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | quilmana
# Processing Record 9 of Set 2 | coihueco
# Processing Record 10 of Set 2 | kambja
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | jumla
# Processing Record 15 of Set 2 | pemangkat
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | khandyga
# Processing Record 19 of Set 2 | kaitangata
# Processing Record 20 of Set 2 | sorland
# Processing Record 21 of Set 2 | ondjiva
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | katsuura
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | longlac
# 'coord'
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | betare oya
# Processing Record 29 of Set 2 | xam nua
# Processing Record 30 of Set 2 | san policarpo
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | port alfred
# Processing Record 33 of Set 2 | sawakin
# Processing Record 34 of Set 2 | chaah
# Processing Record 35 of Set 2 | pilar
# Processing Record 36 of Set 2 | asheville
# Processing Record 37 of Set 2 | belushya guba
# 'coord'
# Processing Record 38 of Set 2 | clyde river
# Processing Record 39 of Set 2 | illoqqortoormiut
# 'coord'
# Processing Record 40 of Set 2 | havelock
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | kayes
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | alice springs
# Processing Record 47 of Set 2 | dunedin
# Processing Record 48 of Set 2 | teplyk
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | moron
# Processing Record 1 of Set 3 | lavrentiya
# Processing Record 2 of Set 3 | flinders
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | matara
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | bonfim
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | bednodemyanovsk
# 'coord'
# Processing Record 10 of Set 3 | krasnoborsk
# Processing Record 11 of Set 3 | sitka
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | morristown
# Processing Record 14 of Set 3 | zhezkazgan
# Processing Record 15 of Set 3 | staryy nadym
# Processing Record 16 of Set 3 | alotau
# 'coord'
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | labrea
# Processing Record 19 of Set 3 | adilabad
# Processing Record 20 of Set 3 | shahada
# Processing Record 21 of Set 3 | lasa
# Processing Record 22 of Set 3 | kurchum
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | burnie
# Processing Record 25 of Set 3 | lac du bonnet
# Processing Record 26 of Set 3 | puerto ayora
# Processing Record 27 of Set 3 | arlit
# Processing Record 28 of Set 3 | barra da estiva
# Processing Record 29 of Set 3 | ozuluama
# Processing Record 30 of Set 3 | nanton
# Processing Record 31 of Set 3 | isangel
# Processing Record 32 of Set 3 | golden
# Processing Record 33 of Set 3 | port hardy
# Processing Record 34 of Set 3 | saint-joseph
# Processing Record 35 of Set 3 | sanzieni
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | taolanaro
# 'coord'
# Processing Record 38 of Set 3 | general pico
# Processing Record 39 of Set 3 | vanimo
# Processing Record 40 of Set 3 | yellowknife
# Processing Record 41 of Set 3 | sulangan
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | gillette
# Processing Record 44 of Set 3 | ngukurr
# 'coord'
# Processing Record 45 of Set 3 | qaanaaq
# Processing Record 46 of Set 3 | amderma
# 'coord'
# Processing Record 47 of Set 3 | coahuayana
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | vila velha
# Processing Record 50 of Set 3 | port blair
# Processing Record 1 of Set 4 | sri aman
# Processing Record 2 of Set 4 | rolim de moura
# 'coord'
# Processing Record 3 of Set 4 | santa cruz del sur
# Processing Record 4 of Set 4 | andijon
# Processing Record 5 of Set 4 | rundu
# Processing Record 6 of Set 4 | monroe
# Processing Record 7 of Set 4 | barawe
# 'coord'
# Processing Record 8 of Set 4 | pietarsaari
# Processing Record 9 of Set 4 | longyearbyen
# Processing Record 10 of Set 4 | mehamn
# Processing Record 11 of Set 4 | saint george
# Processing Record 12 of Set 4 | sept-iles
# Processing Record 13 of Set 4 | mayo
# Processing Record 14 of Set 4 | constitucion
# Processing Record 15 of Set 4 | souillac
# Processing Record 16 of Set 4 | jamestown
# Processing Record 17 of Set 4 | ankpa
# Processing Record 18 of Set 4 | panaba
# Processing Record 19 of Set 4 | grand river south east
# 'coord'
# Processing Record 20 of Set 4 | north bend
# Processing Record 21 of Set 4 | san rafael
# Processing Record 22 of Set 4 | geraldton
# Processing Record 23 of Set 4 | manokwari
# Processing Record 24 of Set 4 | antalaha
# Processing Record 25 of Set 4 | los llanos de aridane
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | mocambique
# 'coord'
# Processing Record 28 of Set 4 | mustasaari
# Processing Record 29 of Set 4 | camargo
# Processing Record 30 of Set 4 | ruatoria
# 'coord'
# Processing Record 31 of Set 4 | atambua
# Processing Record 32 of Set 4 | ermelo
# Processing Record 33 of Set 4 | front royal
# Processing Record 34 of Set 4 | louisbourg
# 'coord'
# Processing Record 35 of Set 4 | cape town
# Processing Record 36 of Set 4 | roald
# Processing Record 37 of Set 4 | esperance
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | new norfolk
# Processing Record 40 of Set 4 | bolungarvik
# 'coord'
# Processing Record 41 of Set 4 | rudnya
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | pangnirtung
# Processing Record 44 of Set 4 | vihti
# Processing Record 45 of Set 4 | pasni
# Processing Record 46 of Set 4 | juba
# Processing Record 47 of Set 4 | severo-kurilsk
# Processing Record 48 of Set 4 | dezful
# Processing Record 49 of Set 4 | agadez
# Processing Record 50 of Set 4 | westminster
# Processing Record 1 of Set 5 | wembley
# Processing Record 2 of Set 5 | bambous virieux
# Processing Record 3 of Set 5 | labuhan
# Processing Record 4 of Set 5 | zyryanka
# Processing Record 5 of Set 5 | xining
# Processing Record 6 of Set 5 | bethel
# Processing Record 7 of Set 5 | saint-philippe
# Processing Record 8 of Set 5 | belmonte
# Processing Record 9 of Set 5 | karaul
# 'coord'
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | atar
# Processing Record 12 of Set 5 | dikson
# Processing Record 13 of Set 5 | warqla
# 'coord'
# Processing Record 14 of Set 5 | keller
# Processing Record 15 of Set 5 | pontianak
# Processing Record 16 of Set 5 | half moon bay
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | kavaratti
# Processing Record 19 of Set 5 | kamaishi
# Processing Record 20 of Set 5 | candelaria
# Processing Record 21 of Set 5 | kovdor
# Processing Record 22 of Set 5 | amarante do maranhao
# Processing Record 23 of Set 5 | chifeng
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | mahebourg
# Processing Record 26 of Set 5 | luanda
# Processing Record 27 of Set 5 | mancora
# Processing Record 28 of Set 5 | boguchany
# Processing Record 29 of Set 5 | coihaique
# Processing Record 30 of Set 5 | doha
# Processing Record 31 of Set 5 | tadine
# Processing Record 32 of Set 5 | veinticinco de mayo
# Processing Record 33 of Set 5 | nipawin
# Processing Record 34 of Set 5 | tsihombe
# 'coord'
# Processing Record 35 of Set 5 | karsava
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | melito di porto salvo
# Processing Record 38 of Set 5 | falealupo
# 'coord'
# Processing Record 39 of Set 5 | kenai
# Processing Record 40 of Set 5 | cayenne
# Processing Record 41 of Set 5 | meulaboh
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | noumea
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | tsevie
# Processing Record 46 of Set 5 | eyrarbakki
# Processing Record 47 of Set 5 | najran
# Processing Record 48 of Set 5 | bulungu
# Processing Record 49 of Set 5 | hamilton
# Processing Record 50 of Set 5 | bacuit
# 'coord'
# Processing Record 1 of Set 6 | ambovombe
# Processing Record 2 of Set 6 | naranjito
# Processing Record 3 of Set 6 | kyren
# Processing Record 4 of Set 6 | bac lieu
# Processing Record 5 of Set 6 | springfield
# Processing Record 6 of Set 6 | terrace
# Processing Record 7 of Set 6 | tingrela
# 'coord'
# Processing Record 8 of Set 6 | grand gaube
# Processing Record 9 of Set 6 | bajitpur
# Processing Record 10 of Set 6 | sao filipe
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | san cristobal
# Processing Record 13 of Set 6 | aswan
# Processing Record 14 of Set 6 | ambulu
# Processing Record 15 of Set 6 | emba
# Processing Record 16 of Set 6 | fare
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | dwarka
# Processing Record 19 of Set 6 | bonavista
# Processing Record 20 of Set 6 | palabuhanratu
# 'coord'
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | wahran
# 'coord'
# Processing Record 23 of Set 6 | san patricio
# Processing Record 24 of Set 6 | san pedro
# Processing Record 25 of Set 6 | pringsewu
# Processing Record 26 of Set 6 | rungata
# 'coord'
# Processing Record 27 of Set 6 | nikolskoye
# Processing Record 28 of Set 6 | attawapiskat
# 'coord'
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | kralendijk
# Processing Record 31 of Set 6 | jubayl
# 'coord'
# Processing Record 32 of Set 6 | rawson
# Processing Record 33 of Set 6 | hirara
# Processing Record 34 of Set 6 | pyay
# Processing Record 35 of Set 6 | nchelenge
# Processing Record 36 of Set 6 | sola
# Processing Record 37 of Set 6 | mullaitivu
# 'coord'
# Processing Record 38 of Set 6 | erdenet
# Processing Record 39 of Set 6 | ancud
# Processing Record 40 of Set 6 | faanui
# Processing Record 41 of Set 6 | nicoya
# Processing Record 42 of Set 6 | mahibadhoo
# Processing Record 43 of Set 6 | inderborskiy
# 'coord'
# Processing Record 44 of Set 6 | hervey bay
# Processing Record 45 of Set 6 | fonte boa
# Processing Record 46 of Set 6 | posse
# Processing Record 47 of Set 6 | jurm
# Processing Record 48 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 6 | calama
# Processing Record 50 of Set 6 | sompeta
# Processing Record 1 of Set 7 | saint-augustin
# Processing Record 2 of Set 7 | swellendam
# Processing Record 3 of Set 7 | yulara
# Processing Record 4 of Set 7 | hasaki
# Processing Record 5 of Set 7 | yerkoy
# Processing Record 6 of Set 7 | taoudenni
# Processing Record 7 of Set 7 | alekseyevsk
# Processing Record 8 of Set 7 | yaan
# Processing Record 9 of Set 7 | hearst
# Processing Record 10 of Set 7 | cumberland
# Processing Record 11 of Set 7 | ituni
# 'coord'
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | upernavik
# Processing Record 14 of Set 7 | marystown
# Processing Record 15 of Set 7 | hofn
# Processing Record 16 of Set 7 | moyobamba
# Processing Record 17 of Set 7 | artyk
# 'coord'
# Processing Record 18 of Set 7 | ipixuna
# Processing Record 19 of Set 7 | pimentel
# Processing Record 20 of Set 7 | nemencine
# Processing Record 21 of Set 7 | baft
# Processing Record 22 of Set 7 | adrar
# Processing Record 23 of Set 7 | estevan
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | njombe
# Processing Record 26 of Set 7 | novyy urengoy
# Processing Record 27 of Set 7 | nuuk
# Processing Record 28 of Set 7 | chihuahua
# Processing Record 29 of Set 7 | charters towers
# Processing Record 30 of Set 7 | caucaia
# Processing Record 31 of Set 7 | uren
# Processing Record 32 of Set 7 | hirtshals
# Processing Record 33 of Set 7 | balikpapan
# Processing Record 34 of Set 7 | goderich
# Processing Record 35 of Set 7 | san juan de la maguana
# Processing Record 36 of Set 7 | namuac
# Processing Record 37 of Set 7 | tarakan
# Processing Record 38 of Set 7 | aripuana
# Processing Record 39 of Set 7 | vestmannaeyjar
# Processing Record 40 of Set 7 | urengoy
# Processing Record 41 of Set 7 | acajutla
# Processing Record 42 of Set 7 | grindavik
# Processing Record 43 of Set 7 | teahupoo
# Processing Record 44 of Set 7 | horki
# Processing Record 45 of Set 7 | pandan
# Processing Record 46 of Set 7 | palana
# Processing Record 47 of Set 7 | inhambane
# Processing Record 48 of Set 7 | siniscola
# Processing Record 49 of Set 7 | namibe
# Processing Record 50 of Set 7 | richards bay
# Processing Record 1 of Set 8 | marrakesh
# Processing Record 2 of Set 8 | merauke
# Processing Record 3 of Set 8 | mount isa
# Processing Record 4 of Set 8 | chapleau
# Processing Record 5 of Set 8 | zempoala
# Processing Record 6 of Set 8 | ambon
# Processing Record 7 of Set 8 | jiwani
# Processing Record 8 of Set 8 | jose de freitas
# Processing Record 9 of Set 8 | srednekolymsk
# Processing Record 10 of Set 8 | satitoa
# 'coord'
# Processing Record 11 of Set 8 | bargal
# 'coord'
# Processing Record 12 of Set 8 | khormuj
# 'coord'
# Processing Record 13 of Set 8 | hailar
# Processing Record 14 of Set 8 | havre-saint-pierre
# Processing Record 15 of Set 8 | tirumullaivasal
# Processing Record 16 of Set 8 | meyungs
# 'coord'
# Processing Record 17 of Set 8 | cimislia
# Processing Record 18 of Set 8 | tongling
# Processing Record 19 of Set 8 | iskitim
# Processing Record 20 of Set 8 | yingkou
# Processing Record 21 of Set 8 | haukipudas
# Processing Record 22 of Set 8 | diego de almagro
# Processing Record 23 of Set 8 | tupiza
# Processing Record 24 of Set 8 | wulanhaote
# 'coord'
# Processing Record 25 of Set 8 | margate
# Processing Record 26 of Set 8 | ha tinh
# Processing Record 27 of Set 8 | juquia
# Processing Record 28 of Set 8 | torbay
# Processing Record 29 of Set 8 | codrington
# Processing Record 30 of Set 8 | alderwood manor
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | bathsheba
# Processing Record 33 of Set 8 | det udom
# Processing Record 34 of Set 8 | nizhneyansk
# 'coord'
# Processing Record 35 of Set 8 | matamoros
# Processing Record 36 of Set 8 | kavieng
# Processing Record 37 of Set 8 | ugoofaaru
# Processing Record 38 of Set 8 | gazanjyk
# Processing Record 39 of Set 8 | zhongxing
# Processing Record 40 of Set 8 | dzhusaly
# 'coord'
# Processing Record 41 of Set 8 | namatanai
# Processing Record 42 of Set 8 | deputatskiy
# Processing Record 43 of Set 8 | bhakkar
# Processing Record 44 of Set 8 | tuy hoa
# Processing Record 45 of Set 8 | katherine
# Processing Record 46 of Set 8 | chester
# Processing Record 47 of Set 8 | itarema
# Processing Record 48 of Set 8 | manzil salim
# Processing Record 49 of Set 8 | kendari
# Processing Record 50 of Set 8 | chipata
# Processing Record 1 of Set 9 | shizunai
# Processing Record 2 of Set 9 | burla
# Processing Record 3 of Set 9 | ekhabi
# Processing Record 4 of Set 9 | tautira
# Processing Record 5 of Set 9 | navolato
# Processing Record 6 of Set 9 | elesbao veloso
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | strezhevoy
# Processing Record 9 of Set 9 | berlevag
# Processing Record 10 of Set 9 | afgoye
# 'coord'
# Processing Record 11 of Set 9 | viksoyri
# 'coord'
# Processing Record 12 of Set 9 | villazon
# Processing Record 13 of Set 9 | serra
# Processing Record 14 of Set 9 | koygorodok
# Processing Record 15 of Set 9 | durham
# Processing Record 16 of Set 9 | sao joao da barra
# Processing Record 17 of Set 9 | the pas
# Processing Record 18 of Set 9 | abu samrah
# Processing Record 19 of Set 9 | sorong
# Processing Record 20 of Set 9 | houma
# Processing Record 21 of Set 9 | dudinka
# Processing Record 22 of Set 9 | abu dhabi
# Processing Record 23 of Set 9 | whittlesea
# Processing Record 24 of Set 9 | dois vizinhos
# Processing Record 25 of Set 9 | gawler
# Processing Record 26 of Set 9 | okha
# Processing Record 27 of Set 9 | dicabisagan
# Processing Record 28 of Set 9 | nouakchott
# Processing Record 29 of Set 9 | gazojak
# Processing Record 30 of Set 9 | sur
# Processing Record 31 of Set 9 | nome
# Processing Record 32 of Set 9 | umm jarr
# 'coord'
# Processing Record 33 of Set 9 | pishin
# Processing Record 34 of Set 9 | kaukauna
# Processing Record 35 of Set 9 | fabriano
# Processing Record 36 of Set 9 | iskateley
# Processing Record 37 of Set 9 | krynychky
# Processing Record 38 of Set 9 | chuy
# Processing Record 39 of Set 9 | dingle
# Processing Record 40 of Set 9 | penzance
# Processing Record 41 of Set 9 | tefe
# Processing Record 42 of Set 9 | muzhi
# Processing Record 43 of Set 9 | maarianhamina
# Processing Record 44 of Set 9 | sao gabriel da cachoeira
# Processing Record 45 of Set 9 | aflu
# 'coord'
# Processing Record 46 of Set 9 | ulaangom
# Processing Record 47 of Set 9 | muhos
# Processing Record 48 of Set 9 | inirida
# Processing Record 49 of Set 9 | baiyin
# Processing Record 50 of Set 9 | hohhot
# Processing Record 1 of Set 10 | jieshi
# Processing Record 2 of Set 10 | korla
# Processing Record 3 of Set 10 | port moresby
# Processing Record 4 of Set 10 | wukari
# Processing Record 5 of Set 10 | diamantino
# Processing Record 6 of Set 10 | chokurdakh
# Processing Record 7 of Set 10 | port shepstone
# Processing Record 8 of Set 10 | ibatiba
# Processing Record 9 of Set 10 | waw
# Processing Record 10 of Set 10 | idanre
# Processing Record 11 of Set 10 | caranavi
# Processing Record 12 of Set 10 | rio grande
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | ahuimanu
# Processing Record 15 of Set 10 | nhulunbuy
# Processing Record 16 of Set 10 | vanavara
# Processing Record 17 of Set 10 | livingston
# Processing Record 18 of Set 10 | malkara
# Processing Record 19 of Set 10 | anamur
# Processing Record 20 of Set 10 | ust-ishim
# Processing Record 21 of Set 10 | high level
# Processing Record 22 of Set 10 | nantucket
# Processing Record 23 of Set 10 | yerbogachen
# Processing Record 24 of Set 10 | tarko-sale
# Processing Record 25 of Set 10 | cabedelo
# Processing Record 26 of Set 10 | zhaotong
# Processing Record 27 of Set 10 | kamenka
# Processing Record 28 of Set 10 | georgiyevka
# Processing Record 29 of Set 10 | milingimbi
# 'coord'
# Processing Record 30 of Set 10 | zhanatas
# 'coord'
# Processing Record 31 of Set 10 | pangody
# Processing Record 32 of Set 10 | eldorado
# Processing Record 33 of Set 10 | ranong
# Processing Record 34 of Set 10 | ulladulla
# Processing Record 35 of Set 10 | portree
# Processing Record 36 of Set 10 | afmadu
# 'coord'
# Processing Record 37 of Set 10 | novobelokatay
# Processing Record 38 of Set 10 | tevaitoa
# Processing Record 39 of Set 10 | punta cardon
# Processing Record 40 of Set 10 | dukat
# Processing Record 41 of Set 10 | oktyabrskoye
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | mogadishu
# Processing Record 44 of Set 10 | kauhajoki
# Processing Record 45 of Set 10 | joao pinheiro
# Processing Record 46 of Set 10 | iquique
# Processing Record 47 of Set 10 | tacuarembo
# Processing Record 48 of Set 10 | camocim
# Processing Record 49 of Set 10 | pizarro
# Processing Record 50 of Set 10 | tandil
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | avera
# Processing Record 3 of Set 11 | wanning
# Processing Record 4 of Set 11 | katangli
# Processing Record 5 of Set 11 | porto belo
# Processing Record 6 of Set 11 | taltal
# Processing Record 7 of Set 11 | hamina
# Processing Record 8 of Set 11 | bahia blanca
# Processing Record 9 of Set 11 | jacareacanga
# Processing Record 10 of Set 11 | umm lajj
# Processing Record 11 of Set 11 | san quintin
# Processing Record 12 of Set 11 | praia da vitoria
# Processing Record 13 of Set 11 | guajara-mirim
# 'coord'
# Processing Record 14 of Set 11 | maragogi
# Processing Record 15 of Set 11 | yanan
# 'coord'
# Processing Record 16 of Set 11 | ust-kamchatsk
# 'coord'
# Processing Record 17 of Set 11 | bud
# Processing Record 18 of Set 11 | mezhova
# Processing Record 19 of Set 11 | marin
# Processing Record 20 of Set 11 | sinop
# Processing Record 21 of Set 11 | birao
# Processing Record 22 of Set 11 | northam
# Processing Record 23 of Set 11 | likasi
# Processing Record 24 of Set 11 | nouadhibou
# Processing Record 25 of Set 11 | qiryat motzkin
# Processing Record 26 of Set 11 | tabora
# Processing Record 27 of Set 11 | kahului
# Processing Record 28 of Set 11 | launceston
# Processing Record 29 of Set 11 | aligudarz
# Processing Record 30 of Set 11 | ostrovnoy
# Processing Record 31 of Set 11 | benidorm
# Processing Record 32 of Set 11 | voh
# Processing Record 33 of Set 11 | tabiauea
# 'coord'
# Processing Record 34 of Set 11 | saleaula
# 'coord'
# Processing Record 35 of Set 11 | odweyne
# Processing Record 36 of Set 11 | tessalit
# Processing Record 37 of Set 11 | emerald
# Processing Record 38 of Set 11 | sioux lookout
# Processing Record 39 of Set 11 | yenagoa
# Processing Record 40 of Set 11 | soyo
# Processing Record 41 of Set 11 | conakry
# Processing Record 42 of Set 11 | alyangula
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | sarankhola
# Processing Record 45 of Set 11 | salalah
# Processing Record 46 of Set 11 | zhigalovo
# Processing Record 47 of Set 11 | balayong
# Processing Record 48 of Set 11 | rocha
# Processing Record 49 of Set 11 | vardo
# Processing Record 50 of Set 11 | westport
# Processing Record 1 of Set 12 | bolivar
# Processing Record 2 of Set 12 | znamenskoye
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | bandarbeyla
# Processing Record 5 of Set 12 | nanakuli
# Processing Record 6 of Set 12 | laguna
# Processing Record 7 of Set 12 | trincomalee
# Processing Record 8 of Set 12 | jalu
# Processing Record 9 of Set 12 | egvekinot
# Processing Record 10 of Set 12 | heihe
# Processing Record 11 of Set 12 | andevoranto
# 'coord'
# Processing Record 12 of Set 12 | weyburn
# Processing Record 13 of Set 12 | ihosy
# Processing Record 14 of Set 12 | amga
# Processing Record 15 of Set 12 | valparaiso
# Processing Record 16 of Set 12 | mananara
# Processing Record 17 of Set 12 | vilyuysk
# Processing Record 18 of Set 12 | marcona
# 'coord'
# Processing Record 19 of Set 12 | anchorage
# Processing Record 20 of Set 12 | areka
# Processing Record 21 of Set 12 | yingcheng
# Processing Record 22 of Set 12 | ust-kulom
# Processing Record 23 of Set 12 | san juan
# Processing Record 24 of Set 12 | manta
# Processing Record 25 of Set 12 | morehead
# Processing Record 26 of Set 12 | alberton
# Processing Record 27 of Set 12 | nizhniy kuranakh
# Processing Record 28 of Set 12 | utiroa
# 'coord'
# Processing Record 29 of Set 12 | sahuaripa
# Processing Record 30 of Set 12 | nisia floresta
# Processing Record 31 of Set 12 | rosetta
# Processing Record 32 of Set 12 | san ignacio
# Processing Record 33 of Set 12 | englewood
# Processing Record 34 of Set 12 | kuche
# 'coord'
# Processing Record 35 of Set 12 | solnechnyy
# Processing Record 36 of Set 12 | mizan teferi
# Processing Record 37 of Set 12 | viesca
# Processing Record 38 of Set 12 | nyurba
# Processing Record 39 of Set 12 | barra do corda
# Processing Record 40 of Set 12 | gorontalo
# Processing Record 41 of Set 12 | coquimbo
# Processing Record 42 of Set 12 | erzin
# Processing Record 43 of Set 12 | hargeysa
# Processing Record 44 of Set 12 | dumas
# Processing Record 45 of Set 12 | kajaani
# Processing Record 46 of Set 12 | nioro
# Processing Record 47 of Set 12 | mys shmidta
# 'coord'
# Processing Record 48 of Set 12 | quatre cocos
# Processing Record 49 of Set 12 | catuday
# Processing Record 50 of Set 12 | roma
# Processing Record 1 of Set 13 | fairlie
# Processing Record 2 of Set 13 | mukhen
# Processing Record 3 of Set 13 | suntar
# Processing Record 4 of Set 13 | challans
# Processing Record 5 of Set 13 | tungor
# Processing Record 6 of Set 13 | porbandar
# Processing Record 7 of Set 13 | shenjiamen
# Processing Record 8 of Set 13 | nsukka
# Processing Record 9 of Set 13 | bharatpur
# Processing Record 10 of Set 13 | kirakira
# Processing Record 11 of Set 13 | jequie
# Processing Record 12 of Set 13 | brae
# Processing Record 13 of Set 13 | bafq
# Processing Record 14 of Set 13 | la primavera
# Processing Record 15 of Set 13 | bandar-e lengeh
# Processing Record 16 of Set 13 | verkhnyaya inta
# Processing Record 17 of Set 13 | kushima
# Processing Record 18 of Set 13 | jining
# Processing Record 19 of Set 13 | kryve ozero
# Processing Record 20 of Set 13 | peterhead
# Processing Record 21 of Set 13 | san miguel
# Processing Record 22 of Set 13 | porto velho
# Processing Record 23 of Set 13 | puerto carreno
# Processing Record 24 of Set 13 | ternate
# Processing Record 25 of Set 13 | yanam
# Processing Record 26 of Set 13 | verkhnyaya maksakovka
# Processing Record 27 of Set 13 | addi ugri
# 'coord'
# Processing Record 28 of Set 13 | kahramanmaras
# Processing Record 29 of Set 13 | pryazha
# Processing Record 30 of Set 13 | tasbuget
# 'coord'
# Processing Record 31 of Set 13 | college
# Processing Record 32 of Set 13 | tecoanapa
# Processing Record 33 of Set 13 | guerrero negro
# Processing Record 34 of Set 13 | venado tuerto
# Processing Record 35 of Set 13 | nara
# Processing Record 36 of Set 13 | ostrov
# Processing Record 37 of Set 13 | daru
# Processing Record 38 of Set 13 | broken hill
# Processing Record 39 of Set 13 | tiarei
# Processing Record 40 of Set 13 | pokosnoye
# Processing Record 41 of Set 13 | san-pedro
# Processing Record 42 of Set 13 | olafsvik
# Processing Record 43 of Set 13 | tafalla
# Processing Record 44 of Set 13 | bontang
# Processing Record 45 of Set 13 | lipin bor
# Processing Record 46 of Set 13 | salacgriva
# Processing Record 47 of Set 13 | kloulklubed
# Processing Record 48 of Set 13 | grand-santi
# Processing Record 49 of Set 13 | terra santa
# Processing Record 50 of Set 13 | oxford
# Processing Record 1 of Set 14 | moose factory
# Processing Record 2 of Set 14 | nuevo imperial
# Processing Record 3 of Set 14 | bairiki
# Processing Record 4 of Set 14 | bulgan
# Processing Record 5 of Set 14 | hondo
# Processing Record 6 of Set 14 | aris
# Processing Record 7 of Set 14 | chunskiy
# Processing Record 8 of Set 14 | tumannyy
# 'coord'
# Processing Record 9 of Set 14 | ola
# Processing Record 10 of Set 14 | bosaso
# Processing Record 11 of Set 14 | rincon
# Processing Record 12 of Set 14 | kollam
# Processing Record 13 of Set 14 | thinadhoo
# Processing Record 14 of Set 14 | bilma
# Processing Record 15 of Set 14 | orsk
# Processing Record 16 of Set 14 | tawkar
# 'coord'
# Processing Record 17 of Set 14 | columbus
# Processing Record 18 of Set 14 | torzhok
# Processing Record 19 of Set 14 | thul
# Processing Record 20 of Set 14 | kashi
# Processing Record 21 of Set 14 | chokwe
# Processing Record 22 of Set 14 | sakakah
# Processing Record 23 of Set 14 | xichang
# Processing Record 24 of Set 14 | upington
# Processing Record 25 of Set 14 | tres lagoas
# Processing Record 26 of Set 14 | yeppoon
# Processing Record 27 of Set 14 | shimoda
# Processing Record 28 of Set 14 | gurgan
# 'coord'
# Processing Record 29 of Set 14 | diffa
# Processing Record 30 of Set 14 | luau
# Processing Record 31 of Set 14 | hambantota
# Processing Record 32 of Set 14 | road town
# Processing Record 33 of Set 14 | kampene
# Processing Record 34 of Set 14 | tyukalinsk
# Processing Record 35 of Set 14 | filingue
# Processing Record 36 of Set 14 | manado
# Processing Record 37 of Set 14 | nabire
# Processing Record 38 of Set 14 | baglan
# Processing Record 39 of Set 14 | malanje
# Processing Record 40 of Set 14 | abu kamal
# Processing Record 41 of Set 14 | peniche
# Processing Record 42 of Set 14 | lorengau
# Processing Record 43 of Set 14 | lufilufi
# Processing Record 44 of Set 14 | anadyr
# Processing Record 45 of Set 14 | salinas
# Processing Record 46 of Set 14 | hurghada
# Processing Record 47 of Set 14 | pouso alegre
# Processing Record 48 of Set 14 | panguipulli
# Processing Record 49 of Set 14 | caravelas
# Processing Record 50 of Set 14 | boddam
# Processing Record 1 of Set 15 | new ulm
# Processing Record 2 of Set 15 | viligili
# 'coord'
# Processing Record 3 of Set 15 | cumaribo
# 'coord'
# Processing Record 4 of Set 15 | karratha
# Processing Record 5 of Set 15 | yangambi
# Processing Record 6 of Set 15 | enshi
# Processing Record 7 of Set 15 | port lincoln
# Processing Record 8 of Set 15 | ler
# Processing Record 9 of Set 15 | husavik
# Processing Record 10 of Set 15 | ballina
# Processing Record 11 of Set 15 | vengerovo
# Processing Record 12 of Set 15 | igarka
# Processing Record 13 of Set 15 | sirisia
# 'coord'
# Processing Record 14 of Set 15 | ketchikan
# Processing Record 15 of Set 15 | vostok
# Processing Record 16 of Set 15 | mujiayingzi
# Processing Record 17 of Set 15 | victor harbor
# Processing Record 18 of Set 15 | maniitsoq
# Processing Record 19 of Set 15 | dakoro
# Processing Record 20 of Set 15 | maraa
# Processing Record 21 of Set 15 | lolua
# 'coord'
# Processing Record 22 of Set 15 | dalmatovo
# Processing Record 23 of Set 15 | muli
# Processing Record 24 of Set 15 | boca do acre
# Processing Record 25 of Set 15 | mogzon
# Processing Record 26 of Set 15 | makakilo city
# Processing Record 27 of Set 15 | sharan
# Processing Record 28 of Set 15 | turayf
# Processing Record 29 of Set 15 | flic en flac
# Processing Record 30 of Set 15 | formosa
# Processing Record 31 of Set 15 | vryburg
# Processing Record 32 of Set 15 | akyab
# Processing Record 33 of Set 15 | rio gallegos
# Processing Record 34 of Set 15 | sangamner
# Processing Record 35 of Set 15 | kamenskoye
# 'coord'
# Processing Record 36 of Set 15 | norton
# Processing Record 37 of Set 15 | yongan
# Processing Record 38 of Set 15 | libourne
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Manzanillo  20.3433  -77.1167     91.40        51          81
# 1        Rikitea -23.1203 -134.9692     74.03        72         100
# 2         Atuona  -9.8000 -139.0333     77.38        65           0
# 3        Ahipara -35.1667  173.1667     57.81        90          19
# 4    East London -33.0153   27.9116     65.21        72          99
# 5       Zhigansk  66.7697  123.3711     66.36        68          11
# 6         Lompoc  34.6391 -120.4579     86.02        71           0
# 7       Dangriga  16.9692  -88.2321     83.26        77          97
# 8        Aklavik  68.2191 -135.0107     59.52        43          41
# 9  Leningradskiy  69.3833  178.4167     37.51        86          96
#
#         Description  Wind Speed Country                 Date
# 0     broken clouds       11.97      CU  2022-07-27 19:45:06
# 1   overcast clouds       15.08      PF  2022-07-27 19:36:09
# 2         clear sky       20.74      PF  2022-07-27 19:37:28
# 3        few clouds       16.75      NZ  2022-07-27 19:41:02
# 4   overcast clouds        4.25      ZA  2022-07-27 19:36:09
# 5        few clouds        3.56      RU  2022-07-27 19:45:06
# 6         clear sky       13.00      US  2022-07-27 19:39:59
# 7   overcast clouds       12.62      BZ  2022-07-27 19:45:07
# 8  scattered clouds       17.98      CA  2022-07-27 19:45:07
# 9   overcast clouds        2.84      RU  2022-07-27 19:45:07

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed","Description"]

# %%
city_data_df= city_data_df[new_column_order]

# %%
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Manzanillo      CU  20.3433  -77.1167     91.40        51          81
# 1         Rikitea      PF -23.1203 -134.9692     74.03        72         100
# 2          Atuona      PF  -9.8000 -139.0333     77.38        65           0
# 3         Ahipara      NZ -35.1667  173.1667     57.81        90          19
# 4     East London      ZA -33.0153   27.9116     65.21        72          99
# ..            ...     ...      ...       ...       ...       ...         ...
# 665  Rio Gallegos      AR -51.6226  -69.2181     33.76        63         100
# 666     Sangamner      IN  19.5667   74.2167     75.29        87         100
# 667        Norton      ZW -17.8833   30.7000     53.20        60          15
# 668        Yongan      CN  39.6957  113.6871     59.07        87           1
# 669      Libourne      FR  44.9167   -0.2500     70.30        59           0
#
#      Wind Speed      Description
# 0         11.97    broken clouds
# 1         15.08  overcast clouds
# 2         20.74        clear sky
# 3         16.75       few clouds
# 4          4.25  overcast clouds
# ..          ...              ...
# 665        7.25  overcast clouds
# 666        5.10  overcast clouds
# 667        3.74       few clouds
# 668        1.01        clear sky
# 669       10.13        clear sky
#
# [670 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
